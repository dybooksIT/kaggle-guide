# %% [markdown]
# ## Hello 출력하기
#
# * 다음은 Hello라는 메시지를 출력하는 코드입니다.

# %%
msg1 = 'Hello'
print(msg1)

# %% [markdown]
# ## Hello World! 출력하기
# * 다음은 앞에서 출력한 Hello를 포함해서 Hello World!라는 메시지를 출력하는 코드입니다.

# %%
msg2 = ' World!'
print(msg1 + msg2)

# %% [markdown]
# # 마크다운 사용 예
#
# [링크](https://www.dongyangbooks.com/)를 만들었습니다.
#
# 이미지![이미지 삽입](https://www.dongyangbooks.com/Upload/books/20191223_912125807.jpg)를 넣을 수도 있습니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../input/digit-recognizer/test.csv')
im = df.iloc[0].values.reshape((28, 28))

plt.imshow(im)
plt.show()

# %%
df = pd.read_csv('../input/digit-recognizer/train.csv')
df.label.hist()

# %%
import cupy
cupy.is_available()

# %%
PROJECT_ID = "bigquery-public-data"

from google.cloud import bigquery

bigquery_client = bigquery.Client(project=PROJECT_ID)

dataset_ref = bigquery_client.dataset("hacker_news", project=PROJECT_ID)
dataset = bigquery_client.get_dataset(dataset_ref)

tables = list(bigquery_client.list_tables(dataset))

for table in tables:  
    print(table.table_id)
# Out:
# comments
# full
# full_201510
# stories

# %%
# !pip install soynlp

# %%
import os

os.system("pip install soynlp")

# %%
import sys
sys.path.append("../input/pytorch-bert/pytorch-pretrained-BERT-master/pytorch_pretrained_bert")

# %%
import pytorch_pretrained_bert

pytorch_pretrained_bert.BertTokenizer
